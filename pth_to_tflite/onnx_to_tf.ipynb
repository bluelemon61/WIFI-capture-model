# %% [markdown]
# ```shell
# pip install onnx-tf
# ```

# %%
import numpy as np
np.bool = np.bool_

import onnx
from onnx_tf.backend import prepare

onnx_model_path = "./model.onnx"
tf_model_path = "./target.pb"

onnx_model = onnx.load(onnx_model_path)

tf_rep = prepare(onnx_model)
    
tf_rep.export_graph(tf_model_path)
# Out:
# c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow_probability\python\internal\backend\numpy\dtype.py:112: FutureWarning: In the future `np.str` will be defined as the corresponding NumPy scalar.
#   string = getattr(np, 'str', getattr(np, 'string', None))
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 5
#       2 np.bool = np.bool_
#       4 import onnx
# ----> 5 from onnx_tf.backend import prepare
#       7 onnx_model_path = "./model.onnx"
#       8 tf_model_path = "./target.pb"
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\onnx_tf\__init__.py:1
# ----> 1 from . import backend
#       2 from .version import version as __version__
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\onnx_tf\backend.py:28
#      26 from onnx_tf.common import get_unique_suffix
# ...
